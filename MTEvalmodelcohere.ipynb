# %%
#Loading the devtest files of Flores-200 datasets

import os
import pandas as pd

def load_devtest_files(devtest_directory, specific_files):
    all_data = {}

    for file in specific_files:
        file_path = os.path.join(devtest_directory, file)
        
        if os.path.exists(file_path):
            try:
 
                with open(file_path, 'r', encoding='utf-8') as f:
                    sentences = f.readlines()
                sentences = [sentence.strip() for sentence in sentences if sentence.strip()] 

                all_data[file] = sentences
                print(f"Loaded: {file} with {len(sentences)} sentences")
            except Exception as e:
                print(f"Error loading {file}: {e}")
        else:
            print(f"File not found: {file}")

    return all_data


devtest_directory = r'D:\Machine translation model\flores200_dataset\flores200_dataset\devtest'
specific_files = [
    'eng_Latn.devtest',
    'hin_Deva.devtest',
    'mar_Deva.devtest',
    'guj_Gujr.devtest',
    'ben_Beng.devtest',
    'tel_Telu.devtest',
    'tam_Taml.devtest',
]


loaded_data = load_devtest_files(devtest_directory, specific_files)
# Out:
# Loaded: eng_Latn.devtest with 1012 sentences
# Loaded: hin_Deva.devtest with 1012 sentences
# Loaded: mar_Deva.devtest with 1012 sentences
# Loaded: guj_Gujr.devtest with 1012 sentences
# Loaded: ben_Beng.devtest with 1012 sentences
# Loaded: tel_Telu.devtest with 1012 sentences
# Loaded: tam_Taml.devtest with 1012 sentences

# %%
#Machine translation from English to 5 Indian languages['hin', 'mar', 'guj', 'ben', 'tel', 'tam'] of 150 random samples
#Saving the data into excel files by parallel_dataset_eng_lang

def save_random_samples_to_excel(loaded_data, sample_size=150):
    english_sentences = loaded_data['eng_Latn.devtest']
    
    output_directory = r'D:\Machine translation model\Machine Translation Model\OUTPUT MT'

    sample_size = min(sample_size, len(english_sentences))

    for lang_file, lang_sentences in loaded_data.items():
        if lang_file != 'eng_Latn.devtest':
    
            min_len = min(len(english_sentences), len(lang_sentences))
            if min_len < sample_size:
                print(f"Not enough sentences to sample for {lang_file}. Available: {min_len}")
                continue
            
            english_sample = pd.Series(english_sentences).sample(n=sample_size, random_state=42).reset_index(drop=True)
            lang_sample = pd.Series(lang_sentences).sample(n=sample_size, random_state=42).reset_index(drop=True)

            parallel_df = pd.DataFrame({
                'English': english_sample,
                'Translation': lang_sample
            })

            lang_code = lang_file.split('_')[0]
            excel_filename = os.path.join(output_directory, f'parallel_dataset_eng_{lang_code}.xlsx')
            parallel_df.to_excel(excel_filename, index=False)
            print(f'Saved: {excel_filename} with {len(parallel_df)} entries.')
save_random_samples_to_excel(loaded_data)
# Out:
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_hin.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_mar.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_guj.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_ben.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tel.xlsx with 150 entries.
# Saved: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tam.xlsx with 150 entries.

# %%
#loading the saved excel file of Machine translation

import pandas as pd
import os

def load_parallel_samples(output_directory, languages):
    sampled_data = {}
    for lang_code in languages:
        excel_filename = os.path.join(output_directory, f'parallel_dataset_eng_{lang_code}.xlsx')
        if os.path.exists(excel_filename):
            df = pd.read_excel(excel_filename)
            sampled_data[lang_code] = df
            print(f"Loaded: {excel_filename} with {len(df)} entries.")
        else:
            print(f"File not found: {excel_filename}")
    return sampled_data

output_directory = r'D:\Machine translation model\Machine Translation Model\OUTPUT MT'
languages = ['hin', 'mar', 'guj', 'ben', 'tel', 'tam'] 
sampled_data = load_parallel_samples(output_directory, languages)
# Out:
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_hin.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_mar.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_guj.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_ben.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tel.xlsx with 150 entries.
# Loaded: D:\Machine translation model\Machine Translation Model\OUTPUT MT\parallel_dataset_eng_tam.xlsx with 150 entries.

# %%
import cohere
from nltk.translate.bleu_score import sentence_bleu

cohere_api_key = 'cohere api key'

co = cohere.Client(cohere_api_key)

def evaluate_translation(english_sentence, actual_translation, target_language):
    prompt = f"Please provide a fluent and natural translation of the following English sentence into {target_language}. Only use the following languages: Hindi, Marathi, Bengali, Telugu, Gujarati, and Tamil:\n\n{english_sentence}\n\nTranslation:"

    
    try:
        response = co.generate(
            model='command-r-plus',  
            prompt=prompt,
            max_tokens=100, 
            temperature=0.7, 
        )
        cohere_translation = response.generations[0].text.strip()
        bleu_score = sentence_bleu([actual_translation.split()], cohere_translation.split())
        return bleu_score, cohere_translation
    
    except Exception as e:
        print(f"Error evaluating translation: {e}")
        return None, None


def evaluate_samples_and_save_to_excel(sampled_data, output_directory):
    for lang_code, data in sampled_data.items():
        target_language = lang_code.split('_')[0]
        english_sentences = data['English']
        actual_translations = data['Translation']

        bleu_scores = []
        cohere_translations = []

        for english_sentence, actual_translation in zip(english_sentences, actual_translations):
            bleu_score, cohere_translation = evaluate_translation(english_sentence, actual_translation, target_language)
            bleu_scores.append(bleu_score)
            cohere_translations.append(cohere_translation)

            print(f"Evaluated: {english_sentence} -> {cohere_translation} | BLEU Score: {bleu_score}")

        evaluation_df = pd.DataFrame({
            'English': english_sentences,
            'Actual_Translation': actual_translations,
            'Cohere_Translation': cohere_translations,
            'BLEU_Score': bleu_scores
        })

        excel_filename = os.path.join(output_directory, f'evaluation_eng_{lang_code}.xlsx')
        evaluation_df.to_excel(excel_filename, index=False)
        print(f"Saved evaluation results to: {excel_filename}")


evaluate_samples_and_save_to_excel(sampled_data, output_directory)
# Out:
# Evaluated: Vatican City's population is around 800. It is the smallest independent country in the world and the country with the lowest population. -> वेटिकन सिटी की आबादी लगभग 800 है। यह दुनिया का सबसे छोटा स्वतंत्र देश है और आबादी के हिसाब से सबसे छोटा देश है। | BLEU Score: 3.9435663395006287e-78
# Evaluated: All citizens of Vatican City are Roman Catholic. -> वेटिकन सिटी के सभी नागरिक रोमन कैथोलिक हैं। | BLEU Score: 0.8408964152537145
# Evaluated: It has a notably wide variety of plant communities, due to its range of microclimates, differing soils and varying levels of altitude. -> यहाँ माइक्रोक्लाइमेट्स, अलग-अलग मिट्टी और बदलती ऊंचाई के स्तर के कारण पाए जाने वाले विविध प्रकार के पादप समुदाय हैं। | BLEU Score: 4.777946850498661e-155
# Evaluated: The Amazon River is the second longest and the biggest river on Earth. It carries more than 8 times as much water as the second biggest river. -> अमेज़न नदी पृथ्वी पर दूसरी सबसे लंबी और सबसे बड़ी नदी है। यह दूसरी सबसे बड़ी नदी से 8 गुना ज़्यादा पानी बहाती है। | BLEU Score: 0.5086063349240798
# Evaluated: Lion prides act much like packs of wolves or dogs, animals surprisingly similar to lions (but not other big cats) in behavior, and also very deadly to their prey. -> शेरों के समूह भेड़ियों या कुत्तों के पैक की तरह व्यवहार करते हैं, जो व्यवहार में शेरों से आश्चर्यजनक रूप से मिलते-जुलते हैं (लेकिन अन्य बड़े बिल्लियों से नहीं | BLEU Score: 0.10741976354387396
# Evaluated: It was one of the major stops during Henry Louis Gates' PBS special Wonders of the African World. -> हेन्री लुईस गेट्स के पीबीएस स्पेशल वंडर्स ऑफ़ द अफ्रीकन वर्ल्ड के दौरान यह एक प्रमुख पड़ावों में से एक था। | BLEU Score: 8.071151852430623e-155
# Evaluated: Argentina is well known for having one of the best polo teams and players in the world. -> अर्जेंटीना को दुनिया में सबसे बेहतरीन पोलो टीमों और खिलाड़ियों में से एक का घर होने के लिए जाना जाता है। | BLEU Score: 0.19268479640608693
# Evaluated: Sleep interruption is the process of purposefully awakening during your normal sleep period and falling asleep a short time later (10–60 minutes). -> नींद में व्यवधान वह प्रक्रिया है जिसमें सामान्य नींद के समय के दौरान जानबूझकर जागना और थोड़ी देर बाद (10-60 मिनट) सो जाना शामिल है. | BLEU Score: 3.01323060302619e-78
# Evaluated: For example, “learning” and “socialization” are suggested as important motivations for Internet use (James et al., 1995). -> उदाहरण के लिए, यह सुझाव दिया गया है कि इंटरनेट का उपयोग करने के लिए "सीखना" और "सामाजिककरण" महत्वपूर्ण प्रेरणाएँ हैं (जेम्स एट अल, 1995) | BLEU Score: 2.902214485171525e-78
# Evaluated: After a week of losses in the midterm election, Bush told an audience about the expansion of trade in Asia. -> मध्यावधि चुनाव में हार के एक सप्ताह बाद, बुश ने एक दर्शक समूह को एशिया में व्यापार विस्तार के बारे में बताया। | BLEU Score: 0.3867308630094445
# Evaluated: The village of Haldarsvík offer views of the nearby island Eysturoy and has an unusual octagonal church. -> हाल्डर्सविक गाँव से पास के आइस्टरोय द्वीप का नज़ारा देखा जा सकता है और यहाँ एक अनोखी अष्टभुजीय चर्च भी है। | BLEU Score: 0.15732647746232498
# Evaluated: It states that the most effective place for the main subject is at the intersection of lines dividing the image into thirds vertically and horizontally (see example). -> यह बताता है कि मुख्य विषय के लिए सबसे प्रभावी स्थान उस स्थान पर है जहाँ रेखाएँ एक-तिहाई के अंतराल पर गुज़रती हैं, चाहे वह क्षैतिज हों या अनुप्रस्थ (उद | BLEU Score: 0.2881761264465535
# Evaluated: Regular announcements in the Metro are made only in Catalan, but unplanned disruptions are announced by an automated system in a wide variety of languages including Spanish, English, French, Arabic and Japanese. -> मेट्रो में नियमित घोषणाएँ केवल कैटलन में की जाती हैं, लेकिन अप्लान्ड बाधाओं की घोषणा स्पेनिश, अंग्रेजी, फ्रेंच, अरबी और जापानी सहित कई भाषाओ | BLEU Score: 0.4929319394026969
# Evaluated: One of the main Christian tenets is that wealth should be used to alleviate suffering and poverty and that the monetary funds of the church are there specifically for that reason. -> एक प्रमुख ईसाई सिद्धांत यह है कि धन का उपयोग दुःख और गरीबी को दूर करने के लिए किया जाना चाहिए और चर्च के आर्थिक कोष विशेष रूप से इसी उद्देश्य के लिए ह | BLEU Score: 0.48281061888285387
# Evaluated: NHK also reported that the Kashiwazaki Kariwa nuclear power plant in Niigata prefecture was operating normally. -> एनएचके ने यह भी बताया कि नीगाटा प्रान्त के काशिवाज़ाकी करिवा परमाणु ऊर्जा संयंत्र का सामान्य रूप से संचालन किया जा रहा है. | BLEU Score: 0.178551492991616
# Evaluated: Fortunately, drivers tend to behave within a reasonably consistent range; thus, traffic streams tend to have some reasonable consistency and can be roughly represented mathematically. -> सौभाग्य से, ड्राइवरों के व्यवहार में कुछ समानता होती है; इसलिए, यातायात की धाराओं में कुछ समानता होती है और इसे गणितीय रूप से लगभग दर्शाया जा सकता है. | BLEU Score: 3.808720447985434e-78
# Evaluated: Sadly, as newer methods of writing have emerged, the pencil has been relegated to lesser status and uses. -> दुर्भाग्य से, जैसे-जैसे नए तरीके लिखने के तरीके सामने आए हैं, पेंसिल को नीची स्थिति और उपयोग में डाल दिया गया है। | BLEU Score: 5.875710652399658e-155
# Evaluated: At the same time, the German navy, using mainly U-boats, was trying to stop this traffic. -> इसी समय, जर्मन नेवी, जो मुख्य रूप से यू-बोट्स का इस्तेमाल कर रही थी, इस ट्रैफिक को रोकने की कोशिश कर रही थी. | BLEU Score: 0.3896718812449091
# Evaluated: Using ships to transport goods is by far the most efficient way to move large amounts of people and goods across oceans. -> माल ढोने के लिए जहाज़ों का इस्तेमाल करना महासागरों के पार बड़ी संख्या में लोगों और सामान को ले जाने का अब तक का सबसे कारगर तरीका है। | BLEU Score: 0.287580479894246
# Evaluated: However, the percentage of XDR-TB in the entire group of people with tuberculosis still seems to be low; 6,000 of the total 330,000 people infected at any particular moment in South Africa. -> हालाँकि, पूरे टीबी रोगियों के समूह में XDR-TB का प्रतिशत अभी भी कम लगता है; दक्षिण अफ्रीका में किसी भी विशेष समय पर संक्रमित कुल 330,000 लोगों में से | BLEU Score: 0.42798200233083933
# Evaluated: The bill requires violent video games sold in the state of California to be labeled with a decal reading "18" and makes their sale to a minor punishable by a fine of $1000 per offense. -> यह बिल कैलिफोर्निया राज्य में बेचे जाने वाले हिंसक वीडियो गेम्स पर "18" लिखे एक डिकैल से लैस होने की आवश्यकता करता है और एक नाबालिग को बेचने पर | BLEU Score: 0.1863778417769258
# Evaluated: This is the place the British colonisers took as their own and so if you are looking for evidence of the territory's colonial past, this is a good place to start. -> यह वह स्थान है जिसे ब्रिटिश उपनिवेशकों ने अपना बना लिया था, इसलिए यदि आप क्षेत्र के औपनिवेशिक अतीत के प्रमाण की तलाश में हैं, तो यह शुरू करने का एक अच्छा स्था | BLEU Score: 0.13600287923663473
# Evaluated: During the 1980s he worked on shows such as Taxi, Cheers, and The Tracy Ullman Show. -> 1980 के दशक में, उन्होंने टैक्सी, चीयर्स और द ट्रेसी उल्मैन शो जैसे शोज़ पर काम किया. | BLEU Score: 0.35424204380331065
# Evaluated: Nature-based tourism attracts people interested in visiting natural areas for the purpose of enjoying the scenery, including plant and animal wildlife. -> प्रकृति-आधारित पर्यटन उन लोगों को आकर्षित करता है जो प्राकृतिक क्षेत्रों की यात्रा करने में रुचि रखते हैं ताकि प्राकृतिक दृश्यों का आनंद लिया जा सक | BLEU Score: 2.4067733004877963e-78
# Evaluated: Periodic rhythms, which are not simply responses to external periodic cues, have been documented for most living beings, including bacteria, fungi, plants, and animals. -> अधिकांश जीवित प्राणियों में - जिनमें बैक्टीरिया, फंगी, पौधे और जानवर शामिल हैं - पर्यावरणीय चक्रीय संकेतों के प्रतिक्रिया से अधिक जटिल, चक्रीय | BLEU Score: 3.960596097391885e-155
# Evaluated: Three more bombs exploded near government buildings in a period of two hours. -> दो घंटों की अवधि में सरकारी इमारतों के पास और तीन बम फटे। | BLEU Score: 0.3438931217657843
# Evaluated: Posted speed limits are noticeably lower than in previous and subsequent sections — commonly 35-40 mph (56-64 km/h) — and strict obedience to them is even more important than otherwise. -> स्थापित गति सीमा पिछले और अगले खंडों की तुलना में निश्चित रूप से कम है - आमतौर पर 35-40 मील प्रति घंटा (56-64 किमी/घंटा) - और उनका पालन करना और भी ज़्या | BLEU Score: 3.221205998484106e-78
# Evaluated: Professor Pamela Ferguson of the University of Dundee notes "journalists do seem to be walking a dangerous line if publishing photos etc of suspects." -> डंडी विश्वविद्यालय की प्रोफेसर पैमेला फ़र्ग्युसन नोट करती हैं, "अगर संदिग्धों की तस्वीरें आदि प्रकाशित की जाती हैं तो पत्रकारों को एक खतरनाक रा | BLEU Score: 0.114393421668709
# Evaluated: Goats seem to have been first domesticated roughly 10,000 years ago in the Zagros Mountains of Iran. -> यह प्रतीत होता है कि बकरियों को सबसे पहले लगभग 10,000 साल पहले ईरान के जाग्रोस पर्वत में पालतू बनाया गया था। | BLEU Score: 2.66669249540442e-78
# Evaluated: Due to the underwater topology the return flow is concentrated at a few deeper sections, and a fast current to deep water may form there. -> पानी के नीचे की τοποान्तर के कारण वापसी का प्रवाह कुछ गहरे स्थानों पर केंद्रित होता है, और वहां गहरे पानी में तेज़ धाराएँ बन सकती हैं। | BLEU Score: 0.1271235700108297
# Evaluated: Up means you should start at the tip and push the bow, and down means you should start at the frog (which is where your hand is holding the bow) and pull the bow. -> ऊपर की ओर इशारा करता है कि आपको टिप से शुरू करना चाहिए और तीर को धक्का देना चाहिए, जबकि नीचे की ओर इशारा करता है कि आपको फ्रॉग (जहाँ आपका हाथ तीर पकड़े हुए है) | BLEU Score: 2.6315366499459773e-78
# Evaluated: The cities of Harappa and Mohenjo-daro had a flush toilet in almost every house, attached to a sophisticated sewage system. -> हराप्पा और मोहेंजोदारो के लगभग हर घर में एक फ्लश शौचालय था, जो एक उन्नत सीवेज प्रणाली से जुड़ा हुआ था। | BLEU Score: 0.3135651449525274
# Evaluated: Authorities speculate that this indicates that containers holding uranium fuel at the site may have ruptured and are leaking. -> प्राधिकरणों का अनुमान है कि यह संकेत है कि साइट पर यूरेनियम ईंधन संग्रह करने वाले कंटेनर फट गए हैं और रिसाव हो रहा है. | BLEU Score: 0.12740810460323607
# Evaluated: Germany was a common enemy in World War 2, leading to cooperation between the USSR and USA. With the end of the war the clashes of system, process and culture led to the countries falling out. -> द्वितीय विश्व युद्ध के दौरान जर्मनी एक सामान्य दुश्मन था, जिसने सोवियत संघ और संयुक्त राज्य अमेरिका के बीच सहयोग को बढ़ावा दिया। लेकिन युद | BLEU Score: 2.2581519197462855e-78
# Evaluated: But being placed in the "high tropics" just a few degrees north of equator you will need to deal with both heat (always) and strong sun (when the sky is clear, more rarely). -> लेकिन “उच्च उष्णकटिबंध” में स्थित होने के कारण, जो कि भूमध्य रेखा से केवल कुछ डिग्री उत्तर में है, आपको गर्मी (हमेशा) और तेज धूप (जब आसमान साफ हो | BLEU Score: 0.15204407782622806
# Evaluated: No major damage or injuries have been reported in Tonga, but power was temporarily lost, which reportedly prevented Tongan authorities from receiving the tsunami warning issued by the PTWC. -> टोंगा में कोई बड़ा नुकसान या चोट नहीं बताई गई है, लेकिन बिजली चली जाने से टोंगन प्राधिकरणों को पीटीडब्ल्यूसी द्वारा जारी सुनामी चेतावनी मिलने से र | BLEU Score: 0.13278032341054682
# Evaluated: It is Martelly's fifth CEP in four years. -> यह चार सालों में मार्टेली का पाँचवाँ सीईपी है। | BLEU Score: 9.905379076004965e-155
# Evaluated: Hamilton confirmed Howard University Hospital admitted the patient in stable condition. -> हैमिल्टन ने पुष्टि की कि हावर्ड यूनिवर्सिटी अस्पताल ने स्थिर हालत में मरीज़ को भर्ती किया था। | BLEU Score: 0.3673341329152363
# Evaluated: Women: It is recommended that any women travellers say that they are married, regardless of actual marital status. -> हिंदी: महिलाओं के लिए: यह सुझाव दिया जाता है कि यात्रा करने वाली कोई भी महिला यह कहे कि वह शादीशुदा है, भले ही उसकी वास्तविक Martial स्थिति कुछ भी क्य | BLEU Score: 2.454590450972605e-78
# Evaluated: All of the cave entrances, which were named "The Seven Sisters", are at least 100 to 250 meters (328 to 820 feet) in diameter. -> जिन गुफ़ा के मुख्यद्वारों का नाम "सेवेन सिस्टर्स" रखा गया था, वे सभी कम-से-कम 100 से 250 मीटर (328 से 820 फ़ीट) व्यास के हैं. | BLEU Score: 0.24671540152163365
# Evaluated: Subcultures can be distinctive because of the age, ethnicity, class, location, and/or gender of the members. -> उम्र, जातीयता, वर्ग, स्थान और/अथवा लिंग के कारण उपसंस्कृतियाँ अलग-अलग हो सकती हैं. | BLEU Score: 9.282687447692475e-232
# Evaluated: Her other race, the Giant Slalom, saw her finish in tenth in the women's sitting group with a combined run time of 4:41.30, 2:11.60 minutes slower than first place finisher Austrian Claudia Loesch and 1:09.02 minutes slower than the ninth place finisher Gyöngyi Dani of Hungary. -> जायंट स्लैलोम में उसे महिला बैठे हुए समूह में 4:41.30 के कुल समय के साथ दसवाँ स्थान मिला, जो पहले स्थान पर रही ऑस्ट्रियाई क्लाउडिया लोएश से | BLEU Score: 3.5104413227830155e-155
# Evaluated: He is speculated to make a run for president in 2016. -> 2016 में राष्ट्रपति के रूप में उसके नामांकन की अटकलें हैं। | BLEU Score: 2.7877630425655405e-78
# Evaluated: Biological clocks are self sustaining oscillators which will continue a period of free-running cycling even in the absence of external cues. -> जैविक घड़ियाँ स्व-निर्वहनीय घूमने वाली वस्तुएँ हैं जो बाहरी संकेतों की अनुपस्थिति में भी मुक्त-चालन चक्र जारी रखेंगी। | BLEU Score: 0.13757893447156652
# Evaluated: For Australians, the idea of 'flat white' coffee is foreign. A short black is 'espresso', cappuccino comes heaped high with cream (not froth), and tea is served without milk. -> ऑस्ट्रेलियाई लोगों के लिए, 'फ्लैट व्हाइट' कॉफी की अवधारणा विदेशी है। एक शॉर्ट ब्लैक 'एक्सप्रेसो' है, कैपुचिनो क्रीम (न कि फोम) से भरा | BLEU Score: 0.17038220017752764
# Evaluated: Women should realize that cultural differences may result in what they would consider harassment and it is not uncommon to be followed, grabbed by the arm, etc. -> महिलाओं को यह समझना चाहिए कि सांस्कृतिक अंतर के कारण कुछ ऐसी चीज़ें हो सकती हैं जिन्हें वे उत्पीड़न मान सकती हैं, और यह असामान्य नहीं है कि किसी का पीछा क | BLEU Score: 2.8236820110044233e-78
# Evaluated: Romanticism had a large element of cultural determinism, drawn from writers such as Goethe, Fichte, and Schlegel. -> रोमांटिसिज्म में सांस्कृतिक नियतिवाद का एक बड़ा तत्व था, जो लेखकों जैसे गोएथे, फिक्टे और श्लेगेल से लिया गया था. | BLEU Score: 0.2118008548235711
# Evaluated: At the other end of the spectrum, one morphs into an unrecognizable individual that feels he or she must change everything the team has been doing and make it their own. -> दूसरे छोर पर, कोई एक अपरिचित व्यक्ति में बदल जाता है जिसे लगता है कि उसे टीम द्वारा किए जा रहे काम को बदलना चाहिए और उसे अपना बनाना चाहिए। | BLEU Score: 0.22512925230880118
# Evaluated: Pre-operative transgender people should not expect to pass through the scanners with their privacy and dignity intact. -> पूर्व-शल्य-चिकित्सा समावेशी लिंग व्यक्तियों को यह उम्मीद नहीं करनी चाहिए कि उनकी गोपनीयता और गरिमा बनी रहेगी जब वे स्कैनर से गुजरेंगे. | BLEU Score: 0.2747566801431672
# Evaluated: A course will normally be from 2-5 days and will involve role play, a lot of first aid and sometimes weapons training. -> एक कोर्स आमतौर पर 2 से 5 दिनों का होगा और इसमें भूमिका-निर्वाह, बहुत सारे प्राथमिक चिकित्सा और कभी-कभी हथियारों के प्रशिक्षण शामिल होंगे। | BLEU Score: 0.3449031556199229
# Evaluated: Since there was limited response to this tactic, Germany expected a similar response to its unrestricted submarine warfare. -> इस रणनीति का सीमित प्रतिसाद होने के कारण, जर्मनी ने अपने अनियंत्रित पनडुब्बी युद्ध के प्रति भी एक समान प्रतिक्रिया की उम्मीद की थी. | BLEU Score: 0.17105806367202916
# Evaluated: Dustin "Goldust" Runnels commented that "Luna was as freaky as me...maybe even more...love her and will miss her...hopefully she's in a better place." -> डस्टिन "गोल्डस्ट" रनेल्स ने टिप्पणी की कि "लूना उतना ही अजीब थी जितना मैं ... शायद उससे भी ज्यादा ... मुझे उसकी प्यार है और मुझे उसकी कमी खलेगी ... उम् | BLEU Score: 0.10618375120565259
# Evaluated: Over four million people went to Rome to attend the funeral. -> रोम में चार मिलियन से ज़्यादा लोग अंतिम संस्कार में शामिल होने के लिए गए। | BLEU Score: 0.5828233954152654
# Evaluated: Although pyramid-building in stone continued until the end of the Old Kingdom, the pyramids of Giza were never surpassed in their size and the technical excellence of their construction. -> हालाँकि पुराने साम्राज्य के अंत तक पत्थर की पिरामिड बनाना जारी रहा, लेकिन गीज़ा की पिरामिडों का उनके आकार और निर्माण की तकनीकी उत्कृष्टता में कभ | BLEU Score: 0.26942243852118525
# Evaluated: The only way to get it through faster was to send it as checked luggage. Airline regulations will not allow them to send luggage without a passenger, which is where you come in. -> इसे तेज़ी से भेजने का एकमात्र तरीका यह था कि इसे संदारतले के रूप में भेजा जाए। एयरलाइन नियमों के अनुसार, वे यात्री के बिना सामान नहीं भेज सकते हैं, और यही आपक | BLEU Score: 2.946158283262486e-78
# Evaluated: He referred to the rumors as "political chatter and silliness". -> उन्होंने अफवाहों को "राजनीतिक बातचीत और हास्यास्पद बातें" कहकर संबोधित किया। | BLEU Score: 3.661843723291765e-78
# Evaluated: Since the foundation of Asunción in 1537, Paraguay has managed to keep a lot of its indigenous character and identity. -> 1537 में असुन्सियन की स्थापना के बाद से, पैराग्वे ने अपनी बहुत सी मूल विशेषताएँ और पहचान बरकरार रखी है. | BLEU Score: 0.2773184994807218
# Evaluated: First among its 78 recommendations is that a new diplomatic initiative should be taken before the end of this year to secure Iraq’s borders against hostile interventions and to re-establish diplomatic relations with its neighbors. -> इसकी 78 सिफारिशों में से पहली सिफारिश यह है कि इस साल के अंत तक इराक की सीमाओं को शत्रुतापूर्ण हस्तक्षेप से बचाने और पड़ोसियों के साथ राजनयिक संबं | BLEU Score: 0.10055789857871837
# Evaluated: Two songs from the movie, Audition (The Fools Who Dream) and City of Stars, received nominations for best original song. Lionsgate studio received 26 nominations — more than any other studio. -> फ़िल्म के दो गाने, "ऑडिशन (द फूल्ज़ WHO ड्रीम)" और "सिटी ऑफ़ स्टार्स", सर्वश्रेष्ठ मूल गीत के लिए नामांकित किए गए थे। लायंसगेट स्टूडियो को | BLEU Score: 0.16068789768265918
# Evaluated: Because the dinosaur feathers do not have a well-developed shaft, called a rachis, but do have other features of feathers — barbs and barbules — the researchers inferred the rachis was likely a later evolutionary development that these other features. -> शोधकर्ताओं ने निष्कर्ष निकाला कि डाइनासोर के पंखों में अच्छी तरह से विकसित एक केंद्रीय तंतु, जिसे रैकिस कहा जाता है, नहीं होता है, लेकिन उनमें पंख | BLEU Score: 1.2964355720761367e-78
# Evaluated: The pH level is indicated by the amount of Hydrogen (the H in pH) ions in the tested chemical. -> pH स्तर परीक्षण किए गए रासायनिक पदार्थ में हाइड्रोजन (pH में H) आयनों की मात्रा से संकेतित होता है। | BLEU Score: 1.1484186507842885e-231
# Evaluated: The aspect ratio of this format (dividing by twelve to obtain the simplest whole-number ratio) is therefore said to be 3:2. -> इस फॉर्मेट का आस्पेक्ट रेशियो (बारह से विभाजित करने पर सबसे सरल पूर्णांक अनुपात प्राप्त होता है) इसलिए 3:2 कहा जाता है. | BLEU Score: 0.13961286695498595
# Evaluated: While one experimental vaccine appears able to reduce Ebola mortality, up until now, no drugs have been clearly demonstrated suitable for treating existing infection. -> हालाँकि एक प्रयोगात्मक टीका ईबोला से होने वाली मृत्यु दर को कम करने में सक्षम प्रतीत होता है, फिर भी अब तक कोई दवाई ऐसी नहीं पाई गई है जो स्पष्ट रूप से मौ | BLEU Score: 2.2172596350962164e-78
# Evaluated: Since students are often the most critical audience, the blog writer begins to strive to improve writing to avoid criticism. -> क्योंकि विद्यार्थी अक्सर सबसे अधिक आलोचनात्मक श्रोता होते हैं, इसलिए ब्लॉग लेखक अपने लेखन में सुधार लाने का प्रयास करना शुरू कर देता है ताकि आलोचना से | BLEU Score: 0.31453121541441076
# Evaluated: Around 3 minutes into the launch, an on-board camera showed numerous pieces of insulation foam break away from the fuel tank. -> लॉन्च के करीब 3 मिनट बाद, एक ऑन-बोर्ड कैमरे ने दिखाया कि बाहरी ईंधन टैंक से कई इन्सुलेशन फोम के टुकड़े अलग हो गए थे. | BLEU Score: 0.22934769499188126
# Evaluated: Liggins followed in his father’s footsteps and entered a career in medicine. -> लिगिंस ने अपने पिता के पदचिन्हों पर चलते हुए चिकित्सा क्षेत्र में करियर शुरू किया। | BLEU Score: 3.6170146665513074e-78
# Evaluated: He arrived in the US with 4 cents to his name, a book of poetry, and a letter of recommendation from Charles Batchelor (his manager in his previous job) to Thomas Edison. -> वह 4 सेंट, एक कविता पुस्तक, और चार्ल्स बैचेलर (अपनी पिछली नौकरी में उसके मैनेजर) से थॉमस एडिसन के नाम एक सिफारिश पत्र के साथ अमेरिका पहुँचा। | BLEU Score: 5.019362538473707e-155
# Evaluated: With only eighteen medals available a day, a number of countries have failed to make the medal podium. -> केवल अठारह पदक एक दिन के लिए उपलब्ध हैं, कई देशों ने पदक पódium नहीं बनाया है. | BLEU Score: 6.316384078529366e-155
# Evaluated: Science’s main goal is to figure out the way the world works through the scientific method. This method in fact guides most scientific research. -> विज्ञान का मुख्य लक्ष्य यह पता लगाना है कि विश्व वैज्ञानिक पद्धति के माध्यम से कैसे कार्य करता है। यह पद्धति वास्तव में अधिकतर वैज्ञानिक अनुसंधा | BLEU Score: 0.23500581716454064
# Evaluated: Lakkha Singh presented the chhappan bhog bhajan as well. Singer, Raju Khandelwal was accompanying him. -> लक्खा सिंह ने भी छप्पन भोग भजन प्रस्तुत किया. गायक राजू खंडेलवाल ने उनका साथ दिया. | BLEU Score: 5.195166368004445e-78
# Evaluated: A doctor who worked at Children's Hospital of Pittsburgh, Pennsylvania will be charged with aggravated murder after her mother was found dead in the trunk of her car Wednesday, authorities in Ohio say. -> पेंसिल्वेनिया के पिट्सबर्ग में चिल्ड्रेन्स हॉस्पिटल में काम करने वाली एक डॉक्टर पर आरोप लगाया जाएगा कि बुधवार को उसकी माँ को उसकी कार के डिक्की म | BLEU Score: 4.376465758046294e-155
# Evaluated: The early reports say the plane was diverted back to Afghanistan after being denied an emergency landing in Ürümqi. -> प्रारंभिक रिपोर्टों के अनुसार, विमान को Ürümqi में आपातकालीन लैंडिंग से इनकार कर दिए जाने के बाद अफ़गानिस्तान वापस भेज दिया गया था. | BLEU Score: 0.29042767355630905
# Evaluated: In 1624,Dutch East India Company establishes a base in southwestern Taiwan, initiating a transformation in aboriginal grain production practices and employing Chinese laborers to work on its rice and sugar plantations. -> 1624 में, डच ईस्ट इंडिया कंपनी ने ताइवान के दक्षिण-पश्चिमी हिस्से में एक अड्डा स्थापित किया, जिससे आदिवासी अनाज उत्पादन प्रथाओं में एक परिवर्तन शु | BLEU Score: 0.1375533216553798
# Evaluated: Bishkek was described as sinking into a state of "anarchy" by one observer, as gangs of people roamed the streets and plundered stores of consumer goods. -> एक दर्शक ने बिश्केक का वर्णन "अनार्ची" की स्थिति में डूब रहा है के रूप में किया, क्योंकि लोगों के गिरोह सड़कों पर घूम रहे थे और उपभोक्ता सामानों की द | BLEU Score: 2.015456226333724e-78
# Evaluated: The idea of skiing is very old — cave paintings depicting skiers date back as far as 5000 BC! -> स्कीइंग का विचार बहुत पुराना है - गुफा चित्र जो स्कीयर को दिखाते हैं वे 5000 BC तक के हैं! | BLEU Score: 0.4315229271655712
# Evaluated: In particular, it is claimed that one can detect whether a person is lying by interpreting micro-expressions correctly. -> विशेष रूप से, यह दावा किया जाता है कि किसी व्यक्ति के झूठ बोलने की बात को सही तरीके से माइक्रो-एक्सप्रेशन को समझकर पकड़ा जा सकता है. | BLEU Score: 0.3580790443627617
# Evaluated: Shooters in the supplementary pest control trial were to be closely supervised by rangers, as the trial was monitored and its effectiveness evaluated. -> अनुपूरक कीट नियंत्रण परीक्षण में शूटरों पर रेंजरों की करीबी निगरानी रखी जानी थी, क्योंकि परीक्षण की निगरानी की जा रही थी और इसकी प्रभावशीलता का मूल्यांकन कि | BLEU Score: 0.302092675302856
# Evaluated: İzmir is the third largest city in Turkey with a population of around 3.7 million, the second biggest port after Istanbul, and a very good transport hub. -> इज़मिर तुर्की का तीसरा सबसे बड़ा शहर है, जहाँ की आबादी लगभग 37 लाख है, यह इस्तांबुल के बाद दूसरा सबसे बड़ा बंदरगाह है, और यह एक बहुत ही अच्छा परिवहन केंद्र भी है। | BLEU Score: 0.47394794278474006
# Evaluated: During his trip, Iwasaki ran into trouble on many occasions. -> अपनी यात्रा के दौरान, इवासाकी को कई बार परेशानियों का सामना करना पड़ा। | BLEU Score: 0.31455601883230705
# Evaluated: It is related to but usually not involving alpine style ski touring or mountaineering, the latter ones done in steep terrain and requiring much stiffer skis and boots. -> यह अल्पाइन शैली की स्की टूरिंग या पर्वतारोहण से संबंधित है, लेकिन आमतौर पर इसमें इनका उपयोग नहीं होता है, जिन्हें खड़ी भूमि पर किया जाता है और जिसमें अधिक सख् | BLEU Score: 0.23354983512807637
# Evaluated: Any amendments or requests though should be coursed through the travel agent first and not directly with the hotel. -> हालाँकि, कोई भी संशोधन या अनुरोध पहले यात्रा एजेंट के माध्यम से किया जाना चाहिए, न कि सीधे होटल से. | BLEU Score: 0.4384790478296514
# Evaluated: Downhill snowsports, which include skiing and snowboarding, are popular sports involving sliding down snow-covered terrain with skis or a snowboard attached to your feet. -> स्कीइंग और स्नोबोर्डिंग को मिलाकर जो खेल बनता है उसे डाउनहिल स्नोस्पोर्ट्स कहते हैं, और ये बहुत लोकप्रिय हैं. ये खेल बर्फ से ढकी ढलानों पर स्कीज | BLEU Score: 1.9516176360805432e-78
# Evaluated: Middle order batsmen, Sachin Tendulkar and Rahul Dravid, performed well and made a hundred-run partnership. -> मध्यम क्रम के बल्लेबाज़ सचिन तेंदुलकर और राहुल द्रविड़ ने शानदार प्रदर्शन किया और एक शतकीय साझेदारी निभाई। | BLEU Score: 0.39317519708167065
# Evaluated: Police superintendent Chandra Shekhar Solanki said the accused appeared in court with covered faces. -> पुलिस अधीक्षक चंद्रशेखर सोलंकी ने कहा कि आरोपियों ने अपने चेहरे ढके हुए थे जब वे अदालत में पेश हुए थे. | BLEU Score: 0.3386854985606571
# Evaluated: But, after losing the captain's wicket India only made 36 runs loosing 7 wickets to end the innings. -> लेकिन, कप्तान का विकेट गंवाने के बाद, भारत ने 7 विकेट खोकर सिर्फ 36 रन बनाए और अपनी पारी समाप्त की. | BLEU Score: 0.208795826063924
# Evaluated: The main local beer is 'Number One', it is not a complex beer, but pleasant and refreshing. The other local beer is called "Manta". -> मुख्य स्थानीय बियर 'नंबर वन' है, यह एक जटिल बियर नहीं है, लेकिन स्वादिष्ट और तरोताजा है। दूसरी स्थानीय बियर का नाम "मंता" है। | BLEU Score: 3.118082382844508e-78
# Evaluated: Soon after the outbreak of hostilities, Britain initiated a naval blockade of Germany. -> शत्रुता प्रारंभ होने के तुरंत बाद, ब्रिटेन ने जर्मनी की नौसैनिक घेराबंदी शुरू की। | BLEU Score: 0.4574563333993253
# Evaluated: Voyagers planning sex reassignment surgery abroad must ensure they're carrying valid documents for the return trip. -> वॉयेजर्स जो विदेश में लिंग परिवर्तन शल्य चिकित्सा कराना चाहते हैं, उन्हें सुनिश्चित करना चाहिए कि उनके पास वापसी यात्रा के लिए मान्य दस्तावेज | BLEU Score: 0.21264457689012017
# Evaluated: Last month a presidential commission recommended the prior CEP's resignation as part of a package of measures to move the country towards new elections. -> पिछले महीने, एक राष्ट्रपति आयोग ने पिछले CEP के इस्तीफे की सिफारिश की थी, जो देश में नए चुनाव कराने के लिए एक पैकेज में शामिल था। | BLEU Score: 1.331091014027761e-231
# Evaluated: The distinct characteristics of the Internet lead to additional dimensions in terms of the uses and gratifications approach. -> इंटरनेट की विशिष्ट विशेषताएं उपयोग और प्रतिपूर्ति के दृष्टिकोण में अतिरिक्त आयाम जोड़ती हैं। | BLEU Score: 6.758287940460984e-155
# Evaluated: Cuomo, 53, began his governorship earlier this year and signed a bill last month legalizing same-sex marriage. -> ५३ वर्षीय क्यूओमो ने इस वर्ष के पूर्वार्ध में राज्यपाल के रूप में अपना कार्यकाल प्रारंभ किया और पिछले महीने समान लिंगी विवाह को वैधता प्रदान करन | BLEU Score: 0.12022604964426993
# Evaluated: Boating is a national pastime in Finland, with a boat to every seven or eight people. -> फ़िनलैंड में नौका विहार राष्ट्रीय मनोरंजन है, जहाँ सात या आठ लोगों पर एक नाव है. | BLEU Score: 0.4160190882715712
# Evaluated: This is an important way to distinguish between some verbs and objects. -> यह कुछ क्रियाओं और वस्तुओं के बीच अंतर करने का एक महत्वपूर्ण तरीका है। | BLEU Score: 0.7825422900366437
# Evaluated: However, this does not come cheap: as rough rules of thumb, you can expect to pay up to four times the normal economy fare for business, and eleven times for first class! -> हालाँकि, यह सस्ता नहीं है: एक अनुमान के रूप में, आप बिजनेस क्लास के लिए सामान्य अर्थव्यवस्था शुल्क का चार गुना और प्रथम श्रेणी के लिए ग्यारह गुना तक भ | BLEU Score: 0.4451072708211871
# Evaluated: You may also wish to consult the advice of governments other than your own, but their advice is designed for their citizens. -> आप अपनी सरकार के अलावा अन्य सरकारों से सलाह लेना चाह सकते हैं, लेकिन उनकी सलाह उनके नागरिकों के लिए होती है। | BLEU Score: 0.20357625523766523
# Evaluated: If you only go ashore using shipboard excursions you will not need a separate visa (as of 2009). -> अगर आप केवल शिपबोर्ड एक्सक्यूर्ज़न का इस्तेमाल करके जाने की योजना बना रहे हैं तो आपको अलग से वीज़ा की ज़रूरत नहीं होगी (2009 तक). | BLEU Score: 0.19940445989088912
# Evaluated: The strain of bird flu lethal to humans, H5N1, has been confirmed to have infected a dead wild duck, found on Monday, in marshland near Lyon in the east of France. -> पूर्वी फ्रांस के लियोन के पास दलदली भूमि में सोमवार को एक मरे हुए जंगली बत्तख में H5N1 प्रकार के पक्षी फ्लू की उपस्थिति की पुष्टि की गई है, जो मनुष | BLEU Score: 0.30950920105373303
# Evaluated: Foster care is supposed to provide all the necessities that were lacking in the home they were previously taken from. -> यह माना जाता है कि फोस्टर केयर में सभी आवश्यक सुविधाएँ मुहैया कराई जाएंगी जो कि पहले उनके घर में उपलब्ध नहीं थीं जहाँ से उन्हें लाया गया था. | BLEU Score: 0.1585266710543935
# Evaluated: The work done was mostly theoretical, but the program was written to simulate observations made of the Sagittarius galaxy. -> यह कार्य मुख्य रूप से सैद्धांतिक था, लेकिन कार्यक्रम को तीरधनुष गैलेक्सी के निरीक्षणों को निर्मित करने के लिए लिखा गया था। | BLEU Score: 4.123000871113193e-78
# Evaluated: Historians have criticized past FBI policies for focusing resources on cases which are easy to solve, especially stolen car cases, with the intent of boosting the agency's success rate. -> इतिहासकारों ने पिछली FBI नीतियों की आलोचना की है क्योंकि उन्होंने संसाधनों को आसानी से सुलझाए जा सकने वाले मामलों पर केंद्रित किया, खासतौर पर चोरी गए क | BLEU Score: 0.12326794127584526
# Evaluated: A curry is a dish based on herbs and spices, together with either meat or vegetables. -> एक करी एक डिश है जो हर्ब्स और मसालों पर आधारित है, साथ में मीट या वेजिटेबल्स होते हैं | BLEU Score: 5.428795743489114e-155
# Evaluated: A binary number can have only one of two values, i.e. 0 or 1, and these numbers are referred to as binary digits - or bits, to use computer jargon. -> बाइनरी नंबर केवल दो मानों में से एक हो सकता है, अर्थात् 0 या 1, और इन अंकों को बाइनरी अंकों के रूप में जाना जाता है - या, कंप्यूटर शब्दावली का उपयोग करने पर, | BLEU Score: 0.18889796346849766
# Evaluated: Despite leaving the show in 1993 he kept the title of executive producer, and continued to receive tens of millions of dollars every season in royalties. -> हालाँकि उन्होंने 1993 में शो छोड़ दिया था, लेकिन उन्होंने कार्यकारी निर्माता का पद संभाले रखा और रॉयल्टी के रूप में हर सीज़न करोड़ों डॉलर प्रा | BLEU Score: 2.311066579150589e-78
# Evaluated: The official Falklands currency is the Falkland pound (FKP) whose value is set equivalent to that of one British pound (GBP). -> फॉकलैंड आइलैंड्स की आधिकारिक मुद्रा फ़ॉकलैंड पाउंड (एफ़केपी) है, जिसका मूल्य एक ब्रिटिश पाउंड (जीबीपी) के बराबर निर्धारित किया गया है। | BLEU Score: 0.4218752038739219
# Evaluated: The composition of these crystals matches those found in the urine of affected pets when compared by infrared spectroscopy (FTIR). -> इन क्रिस्टल की संरचना इन्फ्रारेड स्पेक्ट्रोस्कोपी (एफटीआईआर) द्वारा प्रभावित पालतू जानवरों के मूत्र में पायी गयी संरचना से मिलती है. | BLEU Score: 0.20689457882828158
# Evaluated: Mosasaurus was the apex predator of its time, so it feared nothing, except other mosasaurs. -> मोसासॉरस अपने समय का शीर्ष शिकारी था, इसलिए उसे किसी से भी डर नहीं था, सिवाय दूसरे मोसासॉरसों के. | BLEU Score: 0.19517971953411034
# Evaluated: We make our houses from plants and make clothes from plants. Most foods that we eat are plants. Without plants, animals could not survive. -> हम पौधों से अपने घर बनाते हैं और पौधों से कपड़े बनाते हैं। हमारे द्वारा खाया जाने वाला अधिकतर भोजन पौधों से ही आता है। पौधों के बिना जानवर जीवित नहीं रह सकते। | BLEU Score: 0.1466669246717799
# Evaluated: Re-entry shock comes on sooner than culture shock (there's less of a honeymoon phase), lasts longer, and can be more severe. -> पुनर्प्रवेश के झटके सांस्कृतिक झटके से पहले आते हैं (एक हनीमून चरण कम होता है), लंबे समय तक रहते हैं, और अधिक गंभीर हो सकते हैं। | BLEU Score: 0.15507977485323482
# Evaluated: A simple popular dinner, especially during the summer, is the Pa amb Oli: Bread with olive oil, tomato, and any available condiments such as cheese, tunafish, etc. -> गर्मियों के दौरान, खासकर रात के खाने में एक लोकप्रिय और सरल विकल्प है "पा अंब ओली": जैतून का तेल, टमाटर और मौजूदा सॉसेज जैसे चीज़, ट्यूनाफिश | BLEU Score: 1.0393942047946774e-231
# Evaluated: Nothing can be seen other than the clear, beautiful sky above and the many surrounding mountains. Very little of this world can be seen or heard from inside the cave. -> आकाश में साफ़ और खूबसूरत नज़ारा और चारों तरफ़ पहाड़ों की मौजूदगी के अलावा कुछ नहीं दिखाई दे रहा था. गुफा के अंदर से इस दुनिया का बहुत कम हिस्सा देखा या सुन | BLEU Score: 2.442264410883572e-78
# Evaluated: The Chaco region was home to other groups of indigenous tribes such as the Guaycurú and Payaguá, who survived by hunting, gathering and fishing. -> चाको क्षेत्र ग्वायकरू और पायागुआ जैसे अन्य मूल निवासी जनजातियों का घर था, जो शिकार, फलों और मछली पकड़ने पर निर्भर थे। | BLEU Score: 0.12000375542055716
# Evaluated: Research in AI involves making machines to automate tasks that require intelligent behavior. -> मशीनों को उन कार्यों को स्वचालित करने के लिए शोध में शामिल हैं जिनमें बुद्धिमान व्यवहार की आवश्यकता होती है। | BLEU Score: 0.49476665153885574
# Evaluated: On the outlying islands credit cards will probably not be accepted, although British and United States currency may be taken; check with the owners in advance to determine what is an acceptable payment method. -> किनारे से दूर स्थित द्वीपों पर शायद क्रेडिट कार्ड स्वीकार नहीं किए जाएंगे, हालाँकि ब्रिटिश और अमेरिकी मुद्रा को स्वीकार किया जा सकता ह | BLEU Score: 2.493903110269466e-78
# Evaluated: Christmas is one of the most important holidays of Christianity, and is celebrated as the birthday of Jesus. -> क्रिसमस ईसाई धर्म के सबसे महत्वपू्र्ण त्यौहारों में से एक है, और यह यीशु के जन्मदिन के रूप में मनाया जाता है। | BLEU Score: 0.3453064989552128
# Evaluated: Six hostages, including the children and elderly, were released early, as were the Filipino photographers. -> छः बंधकों को - जिनमें बच्चे और बुजुर्ग शामिल थे - और फ़िलिपीनो फ़ोटोग्राफरों को जल्दी रिहा कर दिया गया था. | BLEU Score: 6.373704167435469e-155
# Evaluated: "He [Wales] basically lied to us from the start. First, by acting as if this was for legal reasons. Second, by pretending he was listening to us, right up to his art deletion." -> "वेल्स ने शुरू से ही हमें मूल रूप से धोखा दिया था। पहला, यह दिखावा करने के द्वारा कि यह कानूनी कारणों से था। दूसरा, यह दिखावा करने के द्वारी कि वह हमारी | BLEU Score: 0.12026811958248694
# Evaluated: According to Mick O'Flynn, the Acting Director Park Conservation and Heritage with the NPWS, the four shooters selected for the first shooting operation received comprehensive safety and training instruction. -> एनपीडब्ल्यूएस के अधिकारी निदेशक पार्क संरक्षण और विरासत के मिक ओ'फ्लिन के अनुसार, पहली शूटिंग कार्रवाई के लिए चुने गए चार शूटरों को व्यापक सुरक | BLEU Score: 0.17615667556197442
# Evaluated: Many of the traditions surrounding the holiday have been adopted also by non-believers in Christian countries and non-Christians around the world. -> इस त्यौहार से जुड़ी कई परंपराओं को ईसाई देशों में नास्तिकों और विश्व भर में गैर-ईसाईयों द्वारा भी अपनाया गया है। | BLEU Score: 2.4793973152241416e-78
# Evaluated: There may be more maria on the near side because the crust is thinner. It was easier for lava to rise up to the surface. -> निकटवर्ती भाग में अधिक मारिया हो सकती हैं क्योंकि पाषाणपर्त薄ीन होती है। लावा के लिए सतह तक उठना आसान था। | BLEU Score: 0.13264759167412227
# Evaluated: There are different ways of purifying water, some more effective against specific threats. -> पानी को शुद्ध करने के कई तरीके हैं, और कुछ विशेष खतरों के खिलाफ अधिक प्रभावी होते हैं। | BLEU Score: 0.23914960914330066
# Evaluated: Fire rescue crews eventually doused the fire by 11:35 pm. -> आग पर काबू पाने वाली टीमों ने अंततः 11:35 बजे तक आग बुझा दी. | BLEU Score: 8.365126155282214e-155
# Evaluated: Travellers are strongly advised to be aware of any risk of severe weather affecting their area as they may affect any travel plans. -> यात्रियों को अपने क्षेत्र में भीषण मौसम के किसी भी जोखिम के प्रति सावधान रहने की सलाह दी जाती है, क्योंकि इससे उनकी यात्रा योजनाओं पर प्रभाव पड़ सकता है। | BLEU Score: 0.18335439055362013
# Evaluated: Across the United States of America, there are approximately 400,000 known cases of Multiple Sclerosis (MS), leaving it as the leading neurological disease in younger and middle aged adults. -> संयुक्त राज्य अमेरिका में लगभग 4,00,000 मल्टीपल स्क्लेरोसिस (MS) के ज्ञात मामले हैं, जो इसे युवा और मध्यम आयु वर्ग के व्यस्कों में प्रमुख न्यूरो | BLEU Score: 0.35152338304558356
# Evaluated: The great majority of Hong Kong Island's urban development is densely packed on reclaimed land along the northern shore. -> हाँग काँग द्वीप के शहरी विकास का बहुत बड़ा हिस्सा उत्तरी तट के पुनर्वासित भूमि पर घनी बस्तियों में केंद्रित है. | BLEU Score: 0.24400326592971303
# Evaluated: Built by the Egyptians in the third century BCE, the Great Pyramid is one of many large pyramid structures built to honor dead Pharaoh. -> तीसरी शताब्दी ईसा पूर्व में मिस्र के लोगों द्वारा निर्मित महान पिरामिड कई बड़ी पिरामिड संरचनाओं में से एक है जिसे मृत फिरौन की याद में बनाया गय | BLEU Score: 0.37292184043445764
# Evaluated: Thousands of years ago, a man called Aristarchus said that the Solar System moved around the Sun. -> हज़ारों साल पहले, एक शख़्स जिसे आरिस्टार्कहस कहा जाता था, ने कहा था कि सौर मंडल सूरज के चारों ओर घूमता है। | BLEU Score: 0.4087357519773977
# Evaluated: But the consumer market on laptop computer will be radically varied and changed after ASUS was awarded in the 2007 Taiwan Sustainable Award by Executive Yuan of the Republic of China. -> ASUS को चीन गणराज्य के एक्ज़ीक्यूटिव युआन द्वारा 2007 ताइवान सस्टेनेबल पुरस्कार से सम्मानित किये जाने के बाद लैपटॉप कंप्यूटर के उपभोक | BLEU Score: 2.973881673163627e-78
# Evaluated: Others are alleged to have been brought up by animals; some are said to have lived in the wild on their own. -> कुछ लोगों को जानवरों द्वारा पाला-पोसा गया है, ऐसा दावा किया जाता है; कुछ के बारे में कहा जाता है कि वे अपने स्वयं के जंगल में रहते थे. | BLEU Score: 0.3158075288546444
# Evaluated: Also between each dynasty was an unstable age of divided provinces. The best-known of these periods was the Three Kingdoms epoch taking place for 60 years between the Han and the Jin Dynasty. -> प्रत्येक राजवंश के बीच में भी एक अस्थिर काल था जब प्रांतों का बंटवारा हो गया था। इन सभी अवधियों में सबसे प्रसिद्ध काल था तीन राज्यों का काल जो हान और जिन र | BLEU Score: 2.0315153103748445e-78
# Evaluated: As a result, two fish species have become extinct, and two others have become endangered, including the humpback chub. -> परिणामस्वरूप, दो मछली प्रजातियाँ विलुप्त हो गई हैं, और दो अन्य संकटग्रस्त हो गई हैं, जिसमें हंपबैक चब भी शामिल है। | BLEU Score: 0.31837078586642553
# Evaluated: Blogs can also help improve student writing. While students often begin their blog experience with sloppy grammar and spelling, the presence of an audience generally changes that. -> ब्लॉग स्टूडेंट्स के राइटिंग स्किल्स में सुधार लाने में भी मदद कर सकते हैं. हालाँकि स्टूडेंट्स अक्सर अपने ब्लॉग की शुरुआत गलत ग्रामर और स्पेलिंग के सा | BLEU Score: 1.7939297637002165e-78
# Evaluated: Why would an organization want to go through the time consuming process of establishing a learning organization? One goal for putting organizational learning concepts into practice is innovation. -> एक संगठन क्यों चाहेगा कि वह एक शिक्षण संगठन की स्थापना की समय लेने वाली प्रक्रिया से गुज़रे? नवाचार संगठनात्मक शिक्षण अवधारणाओं को क्रियान्वित करने | BLEU Score: 0.10788500642318005
# Evaluated: As long as you stay in this zone, you can generally cross borders without going through passport control checkpoints again. -> आप जिस क्षेत्र में हैं उसके अंदर रहकर आम तौर पर आप पासपोर्ट नियंत्रण चेक पॉइंट के बिना ही सीमा पार कर सकते हैं. | BLEU Score: 2.69196531103976e-78
# Evaluated: Your local telephone service provider should be able to give more information about connecting to this service. -> आपकी स्थानीय टेलीफोन सेवा प्रदाता को इस सेवा से जुड़ने के बारे में अधिक जानकारी देनी चाहिए. | BLEU Score: 0.3563653702285612
# Evaluated: As the areas are sparsely populated, and light pollution therefore often not a problem, you will also be able to enjoy the stars. -> क्योंकि ये क्षेत्र दूर-दूर तक फैले हुए हैं और प्रकाश प्रदूषण अक्सर समस्या नहीं होता है, इसलिए आप तारों का आनंद भी ले पाएंगे. | BLEU Score: 5.6044837923493534e-155
# Evaluated: If you find yourself resetting the clock in your sleep, it can be placed on the other side of the room, forcing you to get out of bed to turn it off. -> अगर आप पाते हैं कि आप नींद में अलार्म बंद कर रहे हैं, तो आप अलार्म को अपने बिस्तर के दूसरी तरफ रख सकते हैं जिससे कि आपको अलार्म बंद करने के लिए बिस्तर से उठना पड़े. | BLEU Score: 0.20056680014857733
# Evaluated: Current senator and Argentine First Lady Cristina Fernandez de Kirchner announced her presidential candidacy yesterday evening in La Plata, a city 50 kilometers (31 miles) away from Buenos Aires. -> वर्तमान सीनेटर और अर्जेंटीना की प्रथम महिला क्रिस्टीना फर्नांडीज़ डी किर्च्नर ने पिछली रात ला प्लाता में राष्ट्रपति पद के लिए अपनी उम्मीदवारी की | BLEU Score: 0.2378316447313467
# Evaluated: His 1,000th stamp was the magnificent "Great Deeds by Swedish Kings" by David Klöcker Ehrenstrahl in 2000, which is listed in the Guinness Book of World Records. -> 2000 में, उनका 1000वाँ स्टैम्प डेविड क्लॉकर एहरेनश्ट्राहल की बनाई “ग्रेट डीड्स बाई स्वीडिश किंग्स” था, जो गिनीज़ वर्ल्ड रिकॉर्ड्स म | BLEU Score: 4.7219899831800264e-155
# Evaluated: All things considered, we should not be surprised if our own ancestors solved their "protein problem" in somewhat the same way that chimps on the savanna do today. -> हमें आश्चर्य नहीं होना चाहिए अगर हमारे पूर्वजों ने भी अपनी "प्रोटीन समस्या" का समाधान आज सावाना में चिंपांजी के समान ही किया होगा। | BLEU Score: 5.509937940728552e-155
# Evaluated: The announcement was made after Trump had a phone conversation with Turkish President Recep Tayyip Erdoğan. -> ट्रम्प और तुर्की के राष्ट्रपति रजब तैयब एर्दोगन के बीच एक टेलीफ़ोनिक वार्ता के बाद यह घोषणा की गई। | BLEU Score: 0.23662970829944485
# Evaluated: Layton had asked for changes to the conservatives' environmental bill during the meeting with the PM, asking for a "thorough and complete rewriting" of the Conservative party's environmental bill. -> बैठक के दौरान प्रधान मंत्री के साथ, लेटन ने संरक्षिणीयों के पर्यावरण बिल में बदलाव का अनुरोध किया, जिसमें कंज़र्वेटिव पार्टी के पर्यावरण बिल क | BLEU Score: 0.2041920513096475
# Evaluated: Duvall, who is married with two adult children, did not leave a big impression on Miller, to whom the story was related. -> डुवाल, जिनकी शादी हो चुकी है और उनके दो बड़े बच्चे हैं, उन्होंने मिलर पर ज्यादा असर नहीं छोड़ा, जिन्हें यह कहानी सुनाई गई थी. | BLEU Score: 7.57965434483665e-155
# Evaluated: Regional and seasonal severe weather phenomena include blizzards, snowstorms, ice storms, and dust storms. -> क्षेत्रीय और मौसमी गंभीर मौसम की घटनाओं में ब्लिज़र्ड, हिमपात, बर्फ की आंधी और धूल के तूफान शामिल हैं। | BLEU Score: 0.4461660210144737
# Evaluated: Greenland was settled sparsely. In the Norse sagas they say that Erik the Red was exiled from Iceland for murder, and when travelling further west, found Greenland and named it Greenland. -> ग्रीनलैंड की बस्ती बिखरी हुई थी. नॉर्स सागा के अनुसार, एरिक द रेड को हत्या के लिए आइसलैंड से निर्वासित कर दिया गया था, और जब वह और अधिक पश्चिम की ओर गया, त | BLEU Score: 0.17343678200037552
# Evaluated: Adekoya has since been in Edinburgh Sheriff Court charged with murdering her son. -> एडेकोया पर अपने बेटे की हत्या का आरोप है, और तब से वे एडिनबर्ग शेरिफ कोर्ट में पेश किए गए हैं | BLEU Score: 0.2615311775021803
# Evaluated: The secret to their success is the concept of the niche, a special job each cat holds that keeps it from competing with others. -> उनकी सफलता का रहस्य है निच का सिद्धांत, एक ख़ास काम जो हर बिल्ली करती है और जिससे वो एक-दूसरे से प्रतिस्पर्धा करने से बच जाती हैं। | BLEU Score: 3.091006737923933e-78
# Evaluated: Fellow wrestlers also paid tribute to Luna. -> साथी पहलवानों ने भी लूना को श्रद्धांजलि अर्पित की. | BLEU Score: 0.36889397323344053
# Evaluated: According to police, the driver of the vehicle that hit the photographer is unlikely to face criminal charges. -> पुलिस के अनुसार, फोटोग्राफर को टक्कर मारने वाली गाड़ी का ड्राइवर संभवतः आपराधिक आरोपों का सामना नहीं करेगा। | BLEU Score: 2.8448961046641547e-78
# Evaluated: Cochamó Valley - Chile's premier climbing destination, known as the Yosemite of South America, with a variety of granite big walls and crags. -> कोचामो वैली - चिली का प्रमुख चढ़ाई का गंतव्य, जिसे दक्षिण अमेरिका का योसेमाइट कहा जाता है, जहाँ विविध ग्रेनाइट की बड़ी दीवारें और छोटी चट्टान | BLEU Score: 5.5283313369141695e-155
# Evaluated: Sharks do exist, however they rarely attack humans. Most sharks are scared of humans and would swim away. -> हालाँकि शार्क अस्तित्व में हैं, लेकिन वे इंसानों पर कम ही हमला करते हैं | अधिकतर शार्क इंसानों से डरते हैं और भाग जाते हैं | | BLEU Score: 0.1255571913848575
# Saved evaluation results to: D:\Machine translation model\Machine Translation Model\OUTPUT MT\evaluation_eng_hin.xlsx
# Evaluated: Vatican City's population is around 800. It is the smallest independent country in the world and the country with the lowest population. -> वेटिकन सिटीची जनसंख्या करीब ८०० असणार निकलली आहे. ही संसारातील सर्वात लहान स्वतंत्र राष्ट्र आहे आणि ती सर्वात कमी जनसंख्ये वाली राष्ट्र | BLEU Score: 5.035580399326033e-155
# Evaluated: All citizens of Vatican City are Roman Catholic. -> वेटिकन सिटीचे सर्व नागरिक रोमन कॅथलिक आहेत. | BLEU Score: 4.677477553605556e-78
# Evaluated: It has a notably wide variety of plant communities, due to its range of microclimates, differing soils and varying levels of altitude. -> हि माद्रीस च्या भिन्न-भिन्न माइक्रोक्लाइमेट, भिन्न प्रकारची मृत्तिका आणि भिन्न-भिन्न उंचाईच्या निम्नांकी कारणे वनस्पती समु | BLEU Score: 1.029888105212513e-231
# Evaluated: The Amazon River is the second longest and the biggest river on Earth. It carries more than 8 times as much water as the second biggest river. -> अमेज़न नदी पृथ्वी पर दूसरी सबसे लम्बी और सबसे बड़ी नदी है. यह दूसरी सबसे बड़ी नदी से 8 गुना ज़्यादा पानी बहाती है. | BLEU Score: 1.0832677820940877e-231
# Evaluated: Lion prides act much like packs of wolves or dogs, animals surprisingly similar to lions (but not other big cats) in behavior, and also very deadly to their prey. -> सिंहावलोकन माने में भेड़ियों या कुत्तों के झुण्डों जैसा व्यवहार करते है, जिनका व्यवहार सिंहों से आश्चर्यजनक रूप से मिलता-जुलता है (परन्तु अन्य बड़ी बिल् | BLEU Score: 8.944112676602397e-232
# ...
# Evaluated: However, this does not come cheap: as rough rules of thumb, you can expect to pay up to four times the normal economy fare for business, and eleven times for first class! -> எனினும், இது குறைந்த விலையில் கிடைப்பதில்லை: ஒரு சராசரி பொருளாதார கட்டணத்திற்கு நான்கு மடங் | BLEU Score: 4.7929675183923966e-232
# Evaluated: You may also wish to consult the advice of governments other than your own, but their advice is designed for their citizens. -> நீங்கள் தங்கள் அரசாங்கத்தை தவிர மற்ற அரசாங்கங்களிடம் ஆலோசனை பெற விரும்பலாம், ஆனால் | BLEU Score: 2.6616506618872897e-78
# Evaluated: If you only go ashore using shipboard excursions you will not need a separate visa (as of 2009). -> 2009 வரை கப்பலில் ஏற்படுத்தப்பட்ட சுற்றுலாக்களை மட்டுமே நீங்கள் பயன்படுத்தினால், தனி விசா த | BLEU Score: 6.061838450024688e-155
# Evaluated: The strain of bird flu lethal to humans, H5N1, has been confirmed to have infected a dead wild duck, found on Monday, in marshland near Lyon in the east of France. -> ஃபிரான்ஸின் கிழக்குப் பகுதியில் லியோன் அருகே உள்ள ஒரு குளத்தில் மணிவிரிவு திங்களன்று பலி | BLEU Score: 3.360348760350594e-232
# Evaluated: Foster care is supposed to provide all the necessities that were lacking in the home they were previously taken from. -> அவர்கள் முன்பு வைத்திருந்த வீட்டில் இருந்து எடுக்கப்பட்ட அனைத்து அவசிய பொருட்களையும் வளர்ப் | BLEU Score: 8.387826279040936e-232
# Evaluated: The work done was mostly theoretical, but the program was written to simulate observations made of the Sagittarius galaxy. -> செய்யப்பட்ட வேலை பெரும்பாலும் தத்துவார்த்தமானது, ஆனால் சக்டிதருவிற்கான ஒரு நிரல் எழுதப்பட்டது. | BLEU Score: 7.107197028258987e-232
# Evaluated: Historians have criticized past FBI policies for focusing resources on cases which are easy to solve, especially stolen car cases, with the intent of boosting the agency's success rate. -> அறிஞர்கள் பலரும் பின்னர் எஎப்பிஐ கொள்கைகளை கண்டித்துள்ளனர், ஏனெனில் அவை எளிதில் தீர்த | BLEU Score: 0
# Evaluated: A curry is a dish based on herbs and spices, together with either meat or vegetables. -> ஒரு கறி பசுமையான மற்றும் மசாலா பொரிகளை அடிப்படையாகக் கொண்டது, இதனுடன் இதயம் அல்லது காய்கற | BLEU Score: 1.3466796774819026e-231
# Evaluated: A binary number can have only one of two values, i.e. 0 or 1, and these numbers are referred to as binary digits - or bits, to use computer jargon. -> பினரி எண்ணுக்கு இரண்டு மதிப்புகளில் ஒன்று மட்டுமே இருக்க முடியும், அதாவது 0 அல்லது 1, மற்றும | BLEU Score: 1.0066309198761451e-78
# Evaluated: Despite leaving the show in 1993 he kept the title of executive producer, and continued to receive tens of millions of dollars every season in royalties. -> அவர் 1993 ஆம் ஆண்டில் நிகழ்ச்சியை விட்டு விலகினாலும், அவர் தயாரிப்பு மேலாளர் பட்டத்தை தக்க வை | BLEU Score: 7.369735890165345e-232
# Evaluated: The official Falklands currency is the Falkland pound (FKP) whose value is set equivalent to that of one British pound (GBP). -> ஃபால்க்லாந்து தீவுகளின் சட்டபூர்வ நாணயம் ஃபால்க்லாந்து பவுண்ட் (ஃப்.கே.பி.) ஆகும், அதன் மதிப | BLEU Score: 7.389560029878221e-232
# Evaluated: The composition of these crystals matches those found in the urine of affected pets when compared by infrared spectroscopy (FTIR). -> இந்த கிரிஸ்டல்களின் நிரூபித்தன்மை மாற்று வகைகளைக் கொண்ட பிராணிகளின் சிறுநீரில் காணப் | BLEU Score: 8.020204191025903e-232
# Evaluated: Mosasaurus was the apex predator of its time, so it feared nothing, except other mosasaurs. -> அதன் காலத்தில் மோசாசோரஸ் உச்ச அச்சுறுத்தியாக இருந்ததால், அது மற்ற மோசாசோரஸ்களைத் | BLEU Score: 3.4601087655008624e-155
# Evaluated: We make our houses from plants and make clothes from plants. Most foods that we eat are plants. Without plants, animals could not survive. -> நாம் நம் வீடுகளை மற்றும் ஆடைகளை பழங்களிலிருந்து செய்கிறோம். நாம் உண்ணும் உணவில் பெர | BLEU Score: 3.8476696299631795e-155
# Evaluated: Re-entry shock comes on sooner than culture shock (there's less of a honeymoon phase), lasts longer, and can be more severe. -> உள்நுழைவு அதிர்ச்சி கலாச்சார அதிர்ச்சியை விட விரைவாக ஏற்படுகிறது (அதில் குறைவான ஓர் தீ | BLEU Score: 0.12416588812571398
# Evaluated: A simple popular dinner, especially during the summer, is the Pa amb Oli: Bread with olive oil, tomato, and any available condiments such as cheese, tunafish, etc. -> ஒரு எளிய பிரபல இரவு உணவு, தீவனம் போன்ற காய்கறிகள், மீன் போன்றவை கிடைக்கும்போது சிவப்பு ம | BLEU Score: 2.765880328664948e-155
# Evaluated: Nothing can be seen other than the clear, beautiful sky above and the many surrounding mountains. Very little of this world can be seen or heard from inside the cave. -> மேலே உள்ள தெளிவான அழகான வானம் மற்றும் அதைச் சுற்றியுள்ள பல மலைகளைத் தவிர வேறு எதுவு | BLEU Score: 1.8823003902190317e-78
# Evaluated: The Chaco region was home to other groups of indigenous tribes such as the Guaycurú and Payaguá, who survived by hunting, gathering and fishing. -> சாக்கோ பகுதியில் குயக்குரு மற்றும் பயாகுவா போன்ற மூத்த மக்களின் குழுக்களும் வசித்தனர், அவ | BLEU Score: 5.294085324363193e-232
# Evaluated: Research in AI involves making machines to automate tasks that require intelligent behavior. -> சிந்தனையாற்றல் உடைய நடவடிக்கைகளை மேற்கொள்ளும் பொருட்டு இயந்திரங்களை உருவாக்குவதே சிந | BLEU Score: 7.445183326929416e-232
# Evaluated: On the outlying islands credit cards will probably not be accepted, although British and United States currency may be taken; check with the owners in advance to determine what is an acceptable payment method. -> சுற்றுப்புற தீவுகளில் கிரெடிட் கார்டுகள் ஏற்றுக்கொள்ளப்படாது என்று கூறினாலும், பிரிட | BLEU Score: 2.8744291130001147e-232
# Evaluated: Christmas is one of the most important holidays of Christianity, and is celebrated as the birthday of Jesus. -> கிறிஸ்துமஸ் கிறிஸ்தவத்தின் மிக முக்கிய விசேஷ நாட்களில் ஒன்றும், இயேசுவின் பிறந்தநாள் | BLEU Score: 4.828970785282294e-155
# Evaluated: Six hostages, including the children and elderly, were released early, as were the Filipino photographers. -> அரையாண்டுக்கு முன்னரே குழந்தைகள், முதியவர்கள் உட்பட ஆறு முகாமைத்துவப் பிரதிநிதிகள் மற்று | BLEU Score: 1.0016022933125248e-231
# Evaluated: "He [Wales] basically lied to us from the start. First, by acting as if this was for legal reasons. Second, by pretending he was listening to us, right up to his art deletion." -> அவர் [வேல்ஸ்] அடிப்படையில் தொடக்கத்திலிரு�ும் எங்களுடன் பொய் சொன்னார். முதலில், இது சட்ட கார� | BLEU Score: 2.0362381018610764e-155
# Evaluated: According to Mick O'Flynn, the Acting Director Park Conservation and Heritage with the NPWS, the four shooters selected for the first shooting operation received comprehensive safety and training instruction. -> என்.பி.டபிள்யூ.எஸ்-ன் நிர்வாக இயக்குநர் (காலாவதி) மிக் ஓ'ஃபிளின்னுடன், முதல் சுடுதல் நடவடிக்க | BLEU Score: 2.7726074572810562e-232
# Evaluated: Many of the traditions surrounding the holiday have been adopted also by non-believers in Christian countries and non-Christians around the world. -> உலகம் முழுவதும் கிறிஸ்தவர்கள் அல்லாதோரும், கிறிஸ்துமஸ் தினத்தைச் சுற்றி இருக்கும் பல மரப | BLEU Score: 3.758805875443702e-155
# Evaluated: There may be more maria on the near side because the crust is thinner. It was easier for lava to rise up to the surface. -> கிரேவிட்டி தோற்றத்தில் அதிக மேரி இருக்கலாம் ஏனெனில் அதன் பூமி தளையாக இருக்கிறது. இதனால் நீ | BLEU Score: 0
# Evaluated: There are different ways of purifying water, some more effective against specific threats. -> நீரை நவீனமயப்படுத்துவதற்கான பல வழிகள் உள்ளன, சில சில விஷேட ஆபத்துகளுக்கு எதிராக சிறந்து | BLEU Score: 1.3165594234639305e-231
# Evaluated: Fire rescue crews eventually doused the fire by 11:35 pm. -> தீயை அணைக்கும் படைகள் இறுதியாக இரவு 11:35 மணிக்கு தீயை அணைத்துவிட்டன. | BLEU Score: 6.08970970641905e-155
# Evaluated: Travellers are strongly advised to be aware of any risk of severe weather affecting their area as they may affect any travel plans. -> நாட்களில் தீவிரமான காலநிலை தாக்கும் வாய்ப்புள்ள பகுதிகளில் பயணிகள் செல்லக்கூடாது என்று வ | BLEU Score: 4.603336663472925e-232
# Evaluated: Across the United States of America, there are approximately 400,000 known cases of Multiple Sclerosis (MS), leaving it as the leading neurological disease in younger and middle aged adults. -> ஐக்கிய அமெரிக்கா முழுவதும், எம்.எஸ். என்றழைக்கப்படும் முதியோர் மற்றும் நடுத்தர வயது பெரும | BLEU Score: 1.919722803672244e-155
# Evaluated: The great majority of Hong Kong Island's urban development is densely packed on reclaimed land along the northern shore. -> ஹாங்காங் தீவின் மிகப் பெரும்பான்மையான நகர்ப்புற வளர்ச்சி வடக்கு கரையோரத்தில் மீட்கப்பட்ட � | BLEU Score: 8.387826279040936e-232
# Evaluated: Built by the Egyptians in the third century BCE, the Great Pyramid is one of many large pyramid structures built to honor dead Pharaoh. -> எகிப்தியர்களால் மூன்றாம் நூற்றாண்டு முன் கட்டப்பட்ட மாபெரும் பிரமிடம், இறந்துபோன பிரம்மா | BLEU Score: 6.3597993332323924e-232
# Evaluated: Thousands of years ago, a man called Aristarchus said that the Solar System moved around the Sun. -> ஆயிரக்கணக்கான ஆண்டுகளுக்கு முன்பு, அரிஸ்டார்கஸ் என்ற ஒரு மனிதர் சூரிய மண்டலம் சூரியனை சுற | BLEU Score: 1.2917956969975423e-231
# Evaluated: But the consumer market on laptop computer will be radically varied and changed after ASUS was awarded in the 2007 Taiwan Sustainable Award by Executive Yuan of the Republic of China. -> ஆனால், எஸ்யூஎஸ் நிறுவனத்துக்கு 2007 ஆம் ஆண்டு சைனா குடியரசின் எக்ஸிக்யூட்டிவ் யுவான் வழங | BLEU Score: 4.7929675183923966e-232
# Evaluated: Others are alleged to have been brought up by animals; some are said to have lived in the wild on their own. -> சிலர் விலங்குகளால் வளர்க்கப்பட்டதாக கூறப்படுகிறார்கள்; சிலர் தனியாக வனத்தில் வாழ்ந்ததாக க� | BLEU Score: 1.1193096620723278e-231
# Evaluated: Also between each dynasty was an unstable age of divided provinces. The best-known of these periods was the Three Kingdoms epoch taking place for 60 years between the Han and the Jin Dynasty. -> ஒவ்வொரு வம்சாவளிக்கிடையிலும் பிரிந்த மாகாணங்களின் தவிப்பான காலம் இருந்தது. இந்தக் காலகட்ட� | BLEU Score: 1.9866600550722573e-232
# Evaluated: As a result, two fish species have become extinct, and two others have become endangered, including the humpback chub. -> எனவே, இரு மீன் இனங்கள் விலுங்குதல் செய்யப்பட்டுள்ளன, மற்றும் இன்னும் இரண்டு இனங்கள் அப | BLEU Score: 7.551114723170368e-232
# Evaluated: Blogs can also help improve student writing. While students often begin their blog experience with sloppy grammar and spelling, the presence of an audience generally changes that. -> பதிவுகள் மாணவர்களின் எழுதும் திறனை மேம்படுத்தவும் உதவலாம். மாணவர்கள் அடிக்கடி தங்கள் பதிவு | BLEU Score: 1.1943238422814571e-78
# Evaluated: Why would an organization want to go through the time consuming process of establishing a learning organization? One goal for putting organizational learning concepts into practice is innovation. -> ஏனெனில், ஒரு கற்றல் அமைப்பை ஏற்படுத்துவது நேரம் திருடும் ஒரு செயலாகும், அதனால்தான் ஒரு அமைப்ப | BLEU Score: 6.495791299349845e-232
# Evaluated: As long as you stay in this zone, you can generally cross borders without going through passport control checkpoints again. -> நீங்கள் இந்த மட்டத்திலேயே இருக்கும் வரை, பாஸ்போர்ட் கட்டுப்பாட்டு சோதனை நிலையங்கள் மூலம | BLEU Score: 2.8638898911433973e-155
# Evaluated: Your local telephone service provider should be able to give more information about connecting to this service. -> இந்த சேவையை இணைப்பது தொடர்பான மேலும் தகவல்களை உங்கள் உள்ளூர் தொலைபேசி சேவை வழங்கு� | BLEU Score: 0.2249926827428437
# Evaluated: As the areas are sparsely populated, and light pollution therefore often not a problem, you will also be able to enjoy the stars. -> அந்த பகுதிகள் அரைவெறுமையாக இருப்பதால், ஒளி மாசுபாடு பொதுவாக பிரச்சினையாக இருக்காது, எனவே � | BLEU Score: 5.054075496608413e-155
# Evaluated: If you find yourself resetting the clock in your sleep, it can be placed on the other side of the room, forcing you to get out of bed to turn it off. -> நீங்கள் உங்கள் உறக்கத்தில் மணியை மீண்டும் அமைக்கிறீர்கள் என்று கண்டுபிடித்தால், அதை அ | BLEU Score: 5.890583108165841e-232
# Evaluated: Current senator and Argentine First Lady Cristina Fernandez de Kirchner announced her presidential candidacy yesterday evening in La Plata, a city 50 kilometers (31 miles) away from Buenos Aires. -> நடப்பு செனட்டர் மற்றும் அர்ஜென்டினா நாட்டின் முதல் பெண் கிரிஸ்டினா ஃபெர்னாண்டேஸ் டி கிர | BLEU Score: 1.7632342122190697e-232
# Evaluated: His 1,000th stamp was the magnificent "Great Deeds by Swedish Kings" by David Klöcker Ehrenstrahl in 2000, which is listed in the Guinness Book of World Records. -> அவரது 1000-வது தபால் ஓவியம் 2000-ம் ஆண்டில் டேவிட் க்லாக்கர் எரென்ஸ்த்ராஹல் �作 "சுவீடன் மன்னர் | BLEU Score: 4.654437852936961e-232
# Evaluated: All things considered, we should not be surprised if our own ancestors solved their "protein problem" in somewhat the same way that chimps on the savanna do today. -> எல்லா விஷயங்களையும் கருத்தில் கொண்டால், நம் முன்னோர்கள் தங்கள் "புரதம் பிரச்சினை"யை சவானா | BLEU Score: 1.22833511171664e-78
# Evaluated: The announcement was made after Trump had a phone conversation with Turkish President Recep Tayyip Erdoğan. -> ட்ரம்ப் துருக்கி அதிபர் ரஜீப் தையிப் எர்டோகனுடன் தொலைபேசியில் பேசிய பின்னர் அந்த அறிவிப்பு | BLEU Score: 9.918706012922318e-232
# Evaluated: Layton had asked for changes to the conservatives' environmental bill during the meeting with the PM, asking for a "thorough and complete rewriting" of the Conservative party's environmental bill. -> லேட்டன் பிரதமருடனான சந்திப்பின்போது சுற்றுச்சூழல் தொடர்பான சட்டத்தில் மாற்றங்களைக் கோ | BLEU Score: 2.2386076440877334e-232
# Evaluated: Duvall, who is married with two adult children, did not leave a big impression on Miller, to whom the story was related. -> டியூவால், இரண்டு பெரிய குழந்தைகளுடன் திருமணம் செய்துகொண்டவர், கதை சொல்லப்பட்ட மில்லருக்கு | BLEU Score: 3.3271278712336693e-155
# Evaluated: Regional and seasonal severe weather phenomena include blizzards, snowstorms, ice storms, and dust storms. -> பகுதிகளிலும் சீசன்களிலும் கடுமையான வானிலை நிகழ்வுகள் பனிப்புயல், பனிநாற்று, பனிப்பொழிவு, � | BLEU Score: 3.0962413638242046e-155
# Evaluated: Greenland was settled sparsely. In the Norse sagas they say that Erik the Red was exiled from Iceland for murder, and when travelling further west, found Greenland and named it Greenland. -> சிதறிய முகாம்களில் கிரீன்லாந்து குடியேற்றம் செய்யப்பட்டது. நோர்ஸ் சகாஸ்களில், அரிக் ரெ | BLEU Score: 1.2129737545194644e-232
# Evaluated: Adekoya has since been in Edinburgh Sheriff Court charged with murdering her son. -> அடெகோயா அதன் பின்னர் அதன் மகனை கொலை செய்ததற்காக எடின்பரோ செரிப் நீதிமன்றத்தில் குற்றம் ச | BLEU Score: 9.788429383461836e-232
# Evaluated: The secret to their success is the concept of the niche, a special job each cat holds that keeps it from competing with others. -> அவற்றின் வெற்றிக்கு மறைந்திருக்கும் ரகசியம் ஒவ்வொரு பூனைக்கும் வேறுபட்ட ஒரு சிறப்பான வ | BLEU Score: 7.399663116222943e-232
# Evaluated: Fellow wrestlers also paid tribute to Luna. -> தொடர்புடைய மல்யுத்தப் போட்டியாளர்களும் லுனாவுக்கு மரியாதை செலுத்தினர். | BLEU Score: 1.1640469867513693e-231
# Evaluated: According to police, the driver of the vehicle that hit the photographer is unlikely to face criminal charges. -> தமிழ்: போலீஸார் கூறுகையில், புகைப்படக்காரரை இடித்த வாகனத்தின் ஓட்டுனர் அரை மொழிக்கு எதிராக அ | BLEU Score: 1.0003688322288243e-231
# Evaluated: Cochamó Valley - Chile's premier climbing destination, known as the Yosemite of South America, with a variety of granite big walls and crags. -> கொச்சமோ பள்ளத்தாக்கு - தென் அமெரிக்காவின் யோசெமிட்டி என அழைக்கப்படும் சிலியின் முன்னணி ஏ | BLEU Score: 0.11241282151993245
# Evaluated: Sharks do exist, however they rarely attack humans. Most sharks are scared of humans and would swim away. -> சர்க்குகள் உண்மையில் இருக்கின்றன, ஆனால் அவை மனிதர்களை அரிதாகவே தாக்குகின்றன. அதிகாரத்தின் பெ | BLEU Score: 0.15243896465019202
# Saved evaluation results to: D:\Machine translation model\Machine Translation Model\OUTPUT MT\evaluation_eng_tam.xlsx
